# %%
from scipy import stats
from math import *
import numpy as np

# %%
z_score = np.round(stats.norm.ppf(0.025),2)
z_score
# Out:
# -1.96

# %%
mean = 50
std = 40

# %%
sample_size = np.round(((-z_score*std)/(55-mean))**2,0)
sample_size
# Out:
# 246.0
