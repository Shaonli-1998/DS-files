# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot
#plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
sns.set_style('darkgrid') # background
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# importing data
data = pd.read_csv("/content/50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (50, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# # Checking missing values

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# # Checking duplicated values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Rename columns

# %%
data = data.rename({'R&D Spend':'RD_Spend','Marketing Spend':'Marketing_Spend'},axis=1)
data
# Out:
#      RD_Spend  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # Correlation Analysis

# %%
data.corr()
# Out:
#                  RD_Spend  Administration  Marketing_Spend    Profit
# RD_Spend         1.000000        0.241955         0.724248  0.972900
# Administration   0.241955        1.000000        -0.032154  0.200717
# Marketing_Spend  0.724248       -0.032154         1.000000  0.747766
# Profit           0.972900        0.200717         0.747766  1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %% [markdown]
# # Model Building

# %%
model=smf.ols("Profit~RD_Spend+Administration	+Marketing_Spend",data=data).fit()

# %% [markdown]
# # Model Testing

# %%
# Co-efficient of model
model.params
# Out:
# Intercept          50122.192990
# RD_Spend               0.805715
# Administration        -0.026816
# Marketing_Spend        0.027228
# dtype: float64

# %%
# Summary of model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Wed, 13 Mar 2024   Prob (F-statistic):           4.53e-30
# Time:                        02:50:23   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# Finding tvalues and pvalues
print(model.tvalues)
print(model.pvalues)
# Out:
# Intercept           7.626218
# RD_Spend           17.846374
# Administration     -0.525507
# Marketing_Spend     1.655077
# dtype: float64
# Intercept          1.057379e-09
# RD_Spend           2.634968e-22
# Administration     6.017551e-01
# Marketing_Spend    1.047168e-01
# dtype: float64

# %%
# Finding rsquared values
print(model.rsquared)
print(model.rsquared_adj)
# Out:
# 0.9507459940683246
# 0.9475337762901719

# %% [markdown]
# # Since the p value for Administration and Marketing Spend is > 0.05, build simple linear regression and multi-linear regression models  to see insignificant variables

# %%
slr_a=smf.ols("Profit~Administration",data=data).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept         3.040044
#  Administration    1.419493
#  dtype: float64,
#  Intercept         0.003824
#  Administration    0.162217
#  dtype: float64)

# %%
slr_a.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Wed, 13 Mar 2024   Prob (F-statistic):              0.162
# Time:                        02:50:23   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
slr_m=smf.ols("Profit~Marketing_Spend",data=data).fit()
slr_m.tvalues , slr_m.pvalues
# Out:
# (Intercept          7.808356
#  Marketing_Spend    7.802657
#  dtype: float64,
#  Intercept          4.294735e-10
#  Marketing_Spend    4.381073e-10
#  dtype: float64)

# %%
slr_m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Wed, 13 Mar 2024   Prob (F-statistic):           4.38e-10
# Time:                        02:50:23   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# Build the Multi Linear regression model of Adminstration and Marketing together to check for collinearity problem

slr_AM = smf.ols('Profit~Administration+Marketing_Spend',data=data).fit()

# %%
slr_AM.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Wed, 13 Mar 2024   Prob (F-statistic):           2.50e-10
# Time:                        02:50:23   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Model Validation Techniques
# ## Two Techniques 1) Collinearity Check - VIF and 2) Residual Analysis#

# %%
# Collinearity check
rsq_r=smf.ols("RD_Spend~Administration+Marketing_Spend",data=data).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("Administration~RD_Spend+Marketing_Spend",data=data).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("Marketing_Spend~RD_Spend+Administration",data=data).fit().rsquared
vif_m=1/(1-rsq_m)
df={'Variables':['RD_Spend','Administration','Marketing_Spend'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(df)
Vif_df
# Out:
#          Variables       Vif
# 0         RD_Spend  2.468903
# 1   Administration  1.175091
# 2  Marketing_Spend  2.326773

# %%
# Residual Analysis
# Test for Normality of Residuals (Q-Q Plot)
sm.qqplot(model.resid,line='q');
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
# outliar detection from above QQ plot of residuals
list(np.where(model.resid<-10000))
# Out:
# [array([14, 15, 48, 49])]

# %%
# Residual Plot for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()  #User Defined Function Z = (x-mu)/sigma

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# # Residual Vs Regressors

# %%
fig=plt.figure(figsize=(18,5))
sm.graphics.plot_regress_exog(model,'RD_Spend',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(18,5))
sm.graphics.plot_regress_exog(model,'Administration',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(18,5))
sm.graphics.plot_regress_exog(model,'Marketing_Spend',fig=fig)
plt.show()

# %% [markdown]
# # Model Deletion Diagnostics (checking Outliers or Influencers)
# ## 1. Cook's Distance and 2. Leverage value

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
sns.set_style(style='darkgrid')
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# # High Influence Plots

# %%
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543272)

# %%
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=data.shape[1]
n=data.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data[data.index.isin([49])]
# Out:
#     RD_Spend  Administration  Marketing_Spend       State   Profit
# 49       0.0        116983.8         45173.06  California  14681.4

# %% [markdown]
# # Improving Model

# %%
data_update=data.drop(data.index[[49]],axis=0).reset_index(drop=True)
data_update
# Out:
#      RD_Spend  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # Model Deletion Diagoniostics and Final Model

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RD_Spend+Administration+Marketing_Spend",data=data_update).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data_update=data_update.drop(data_update.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data_update
else:
    final_model=smf.ols("Profit~RD_Spend+Administration+Marketing_Spend",data=data_update).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Wed, 13 Mar 2024   Prob (F-statistic):           8.85e-32
# Time:                        02:50:29   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
final_model.rsquared, final_model.rsquared_adj
# Out:
# (0.9613162435129847, 0.9587373264138503)

# %% [markdown]
# # Model Accuracy is increased to 96.13%

# %%
table=pd.DataFrame({'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared],'Rsquared_Adj':[model.rsquared_adj,final_model.rsquared_adj]})
table
# Out:
#    Prep_Models  Rsquared  Rsquared_Adj
# 0        Model  0.950746      0.947534
# 1  Final_Model  0.961316      0.958737

# %% [markdown]
# # Model prediction

# %%
# New data for prediction
new_data=pd.DataFrame({'RD_Spend':104050,"Administration":131588,"Marketing_Spend":50000},index=[0])
new_data
# Out:
#    RD_Spend  Administration  Marketing_Spend
# 0    104050          131588            50000

# %%
final_model.predict(new_data)
# Out:
# 0    132194.031832
# dtype: float64

# %%
pred_y=final_model.predict(data_update)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...
