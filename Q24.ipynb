# %%
from scipy import stats
from math import *

# %%
population_mean = 270
sample_size = 18
sample_mean = 260
sample_std = 90
df = sample_size - 1

# %%
t = (sample_mean - population_mean)/(sample_std/sqrt(sample_size))
t
# Out:
# -0.4714045207910317

# %%
p_value = stats.t.sf(abs(-0.4714045207910317),df)
p_value
# Out:
# 0.32167253567098364
