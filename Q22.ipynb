# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
print('The Z-score of 90% confidence interval is:', np.round(stats.norm.ppf(0.05),4))
# Out:
# The Z-score of 90% confidence interval is: -1.6449

# %%
print('The Z-score of 94% confidence interval is:', np.round(stats.norm.ppf(0.03),4))
# Out:
# The Z-score of 94% confidence interval is: -1.8808

# %%
print('The Z-score of 60% confidence interval is:', np.round(stats.norm.ppf(0.20),4))
# Out:
# The Z-score of 60% confidence interval is: -0.8416
