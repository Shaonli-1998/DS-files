# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv("/content/Q9_a (1).csv")
Data.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   50 non-null     int64
#  1   speed   50 non-null     int64
#  2   dist    50 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB

# %%
Data.describe()
# Out:
#           Index      speed        dist
# count  50.00000  50.000000   50.000000
# mean   25.50000  15.400000   42.980000
# std    14.57738   5.287644   25.769377
# min     1.00000   4.000000    2.000000
# 25%    13.25000  12.000000   26.000000
# 50%    25.50000  15.000000   36.000000
# 75%    37.75000  19.000000   56.000000
# max    50.00000  25.000000  120.000000

# %%
plt.hist(Data)
plt.show()

# %%
sns.boxplot(Data)
# Out:
# <Axes: >

# %%
Data.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
Data.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
print("Skewness in Car's speed column is:",Data['speed'].skew(),"and Kurtosis is:",Data['speed'].kurt())
# Out:
# Skewness in Car's speed data is: -0.11750986144663393 and Kurtosis is: -0.5089944204057617

# %%
print("Skewness in distance column is:",Data['dist'].skew(),"and Kurtosis is:",Data['dist'].kurt())
# Out:
# Skewness in distance column is: 0.8068949601674215 and Kurtosis is: 0.4050525816795765
