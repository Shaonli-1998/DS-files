# %%
from math import *
from scipy import stats

# %%
stats.norm.interval(0.94,200,30/sqrt(2000))
# Out:
# (198.738325292158, 201.261674707842)

# %%
stats.norm.interval(0.98,200,30/sqrt(2000))
# Out:
# (198.43943840429978, 201.56056159570022)

# %%
stats.norm.interval(0.96,200,30/sqrt(2000))
# Out:
# (198.62230334813333, 201.37769665186667)
