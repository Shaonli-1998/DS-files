# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv("/content/Q9_b (1).csv")
Data.head()
# Out:
#    Unnamed: 0          SP         WT
# 0           1  104.185353  28.762059
# 1           2  105.461264  30.466833
# 2           3  105.461264  30.193597
# 3           4  113.461264  30.632114
# 4           5  104.461264  29.889149

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  81 non-null     int64
#  1   SP          81 non-null     float64
#  2   WT          81 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 2.0 KB

# %%
Data.describe()
# Out:
#        Unnamed: 0          SP         WT
# count   81.000000   81.000000  81.000000
# mean    41.000000  121.540272  32.412577
# std     23.526581   14.181432   7.492813
# min      1.000000   99.564907  15.712859
# 25%     21.000000  113.829145  29.591768
# 50%     41.000000  118.208698  32.734518
# 75%     61.000000  126.404312  37.392524
# max     81.000000  169.598513  52.997752

# %%
plt.hist(Data)
plt.show()

# %%
sns.boxplot(Data)
# Out:
# <Axes: >

# %%
Data.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
Data.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
print("Skewness in SP column is:",Data['SP'].skew(),"and Kurtosis is:",Data['SP'].kurt())
# Out:
# Skewness in SP column is: 1.6114501961773586 and Kurtosis is: 2.9773289437871835

# %%
print("Skewness in WT column is:",Data['WT'].skew(),"and Kurtosis is:",Data['WT'].kurt())
# Out:
# Skewness in WT column is: -0.6147533255357768 and Kurtosis is: 0.9502914910300326
