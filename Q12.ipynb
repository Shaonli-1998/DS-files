# %%
import pandas as pd

# %%
data = pd.DataFrame({34,36,36,38,38,39,39,41,41,41,41,42,42,45,49,56})
data
# Out:
#     0
# 0  34
# 1  36
# 2  38
# 3  39
# 4  41
# 5  42
# 6  45
# 7  49
# 8  56

# %%
data.mean()
# Out:
# 0    42.222222
# dtype: float64

# %%
data.median()
# Out:
# 0    41.0
# dtype: float64

# %%
data.std()
# Out:
# 0    6.887993
# dtype: float64

# %%
data.var()
# Out:
# 0    47.444444
# dtype: float64
