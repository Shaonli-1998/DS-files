# %%
from scipy import stats
from math import *

# %%
sample_size = 100
mean = 50
std = 40
std_err = std/sqrt(sample_size)
std_err
# Out:
# 4.0

# %%
p_value = stats.norm.cdf(55,mean,std_err)-stats.norm.cdf(45,mean,std_err)
p_value
# Out:
# 0.7887004526662893

# %%
1-p_value
# Out:
# 0.2112995473337107
