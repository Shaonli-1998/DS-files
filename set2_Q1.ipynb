# %%
from scipy import stats
import numpy as np

# %%
mean = 45
std = 8
x = 50

# %%
z = np.round((x-mean)/std,2)
z
# Out:
# 0.62

# %%
p_value = stats.norm.cdf(z)
p_value
# Out:
# 0.732371106531017

# %%
np.round(1 - p_value,4)
# Out:
# 0.2676
