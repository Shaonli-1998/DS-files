# %%
from scipy import stats
import numpy as np

# %%
mean = 38
std = 6
sample_size = 400

# %%
z_30 = (30-mean)/std
z_30
# Out:
# -1.3333333333333333

# %%
p_value = stats.norm.cdf(z_30)
p_value
# Out:
# 0.09121121972586788

# %%
Number_of_employees = sample_size * p_value
Number_of_employees
# Out:
# 36.484487890347154
